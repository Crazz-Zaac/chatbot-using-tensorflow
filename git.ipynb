# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd gdrive/My Drive/
# %cd ..
# Out:
# [Errno 2] No such file or directory: 'gdrive/My Drive/'
# /content/gdrive/My Drive/Colab Notebooks/Chatbot project
# /content/gdrive/My Drive

# %%
# !ls
# Out:
# '7th sem project report.gdoc'
# 'About HULT 2020.pptx'
# 'Academic Files'
#  Accomplishments
#  acd2a5e1-a1a4-4858-ba7c-f8daf0c13f98_khalti_resized.jpg
#  appsheet
# 'Bank credentials '
#  Book
# 'Chatbot project'
#  citizenship
#  Classroom
#  Code.gscript
# 'Colab Notebooks'
# 'Copy of Apps Script Quickstart: Managing responses for Google Forms.gsheet'
# 'Copy of Copy of Subscripts and Superscripts.gsheet'
# 'Dashain 2077'
# 'Grade 7 (Responses).gsheet'
# 'Important records'
# 'Linear A deciphering project - computational.docx'
# 'LinearA_Project_Code_Complete 2.zip'
# 'Login form.gscript'
# 'Nex Yatra Regular Meeting (fbf-gurn-saj - May 13, 2021).gjam'
# 'nhm-spjh-dko - May 9, 2021 (1).gjam'
# 'nhm-spjh-dko - May 9, 2021.gjam'
# 'Photos 2077'
#  Records
# 'Sanjiwani Computer Book class - 9 Revised-2077.pdf'
# 'School Exam forms'
# 'Software Engineering Solution.pdf'
#  Sundarijal.zip

# %%
# !git clone https://github.com/Crazz-Zaac/chatbot-using-tensorflow.git
# Out:
# Cloning into 'chatbot-using-tensorflow'...
# ...

# %%
# !ls
# Out:
# '7th sem project report.gdoc'
# 'About HULT 2020.pptx'
# 'Academic Files'
#  Accomplishments
#  acd2a5e1-a1a4-4858-ba7c-f8daf0c13f98_khalti_resized.jpg
#  appsheet
# 'Bank credentials '
#  Book
# 'Chatbot project'
#  chatbot-using-tensorflow
#  citizenship
#  Classroom
#  Code.gscript
# 'Colab Notebooks'
# 'Copy of Apps Script Quickstart: Managing responses for Google Forms.gsheet'
# 'Copy of Copy of Subscripts and Superscripts.gsheet'
# 'Dashain 2077'
# 'Grade 7 (Responses).gsheet'
# 'Important records'
# 'Linear A deciphering project - computational.docx'
# 'LinearA_Project_Code_Complete 2.zip'
# 'Login form.gscript'
# 'Nex Yatra Regular Meeting (fbf-gurn-saj - May 13, 2021).gjam'
# 'nhm-spjh-dko - May 9, 2021 (1).gjam'
# 'nhm-spjh-dko - May 9, 2021.gjam'
# 'Photos 2077'
#  Records
# 'Sanjiwani Computer Book class - 9 Revised-2077.pdf'
# 'School Exam forms'
# 'Software Engineering Solution.pdf'
#  Sundarijal.zip

# %%
# %cd chatbot-using-tensorflow
# Out:
# /content/gdrive/My Drive/chatbot-using-tensorflow
