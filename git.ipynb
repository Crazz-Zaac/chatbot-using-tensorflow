# %% [markdown]
# 4/1AY0e-g6XlUV_EEOPppIX0wCDFssBiqHxrf6GXAmlU0OM2kysAE8ZsEvta98

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd gdrive/My Drive/
# %cd ..
# Out:
# /content/gdrive/My Drive
# /content/gdrive

# %%
# !ls
# Out:
# MyDrive

# %%
# %cd MyDrive/
# Out:
# /content/gdrive/MyDrive

# %%
# !ls
# Out:
# '7th sem project report.gdoc'
# 'About HULT 2020.pptx'
# 'Academic Files'
#  Accomplishments
#  acd2a5e1-a1a4-4858-ba7c-f8daf0c13f98_khalti_resized.jpg
#  appsheet
# 'Bank credentials '
#  Book
# 'Chatbot project'
#  chatbot-using-tensorflow
#  citizenship
#  Classroom
#  Code.gscript
# 'Colab Notebooks'
# 'Copy of Apps Script Quickstart: Managing responses for Google Forms.gsheet'
# 'Copy of Copy of Subscripts and Superscripts.gsheet'
# 'Dashain 2077'
# 'Grade 7 (Responses).gsheet'
# 'Important records'
# 'Linear A deciphering project - computational.docx'
# 'LinearA_Project_Code_Complete 2.zip'
# 'Login form.gscript'
# 'Nex Yatra Regular Meeting (fbf-gurn-saj - May 13, 2021).gjam'
# 'nhm-spjh-dko - May 9, 2021 (1).gjam'
# 'nhm-spjh-dko - May 9, 2021.gjam'
# 'Photos 2077'
#  Records
# 'Sanjiwani Computer Book class - 9 Revised-2077.pdf'
# 'School Exam forms'
# 'Software Engineering Solution.pdf'
#  Sundarijal.zip

# %%
# %cd chatbot-using-tensorflow
# Out:
# /content/gdrive/MyDrive/chatbot-using-tensorflow

# %%
# !git config --global user.email 'r.alpha919@gmail.com'

# %%
# !git config --global user.name 'Crazz-Zaac'

# %%
# !git add .

# %%
# !git commit -m "word embedding, named entity recognition and text classification added"
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@c4e2e30d094c.(none)')

# %%
# !git push https://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@github.com/Crazz-Zaac/chatbot-using-tensorflow.git
# Out:
# Counting objects: 7, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (7/7), 5.32 KiB | 1.06 MiB/s, done.
# Total 7 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), done.
# To https://github.com/Crazz-Zaac/chatbot-using-tensorflow.git
#  * [new branch]      master -> master

# %%
# !ls
# Out:
# sample_data
